# %%
import pandas as pd

# %%
df = pd.read_excel('../data/raw_data/excel chat.xlsx')

# %%
df['saludos'][0]
# Out:
# '¡Hola!'

# %%
raw_data = (' ').join(df['saludos']) 
type(raw_data)
# Out:
# str

# %%
raw_data
# Out:
# '¡Hola! Buenos días. Buenas tardes. Buenas noches. ¿Qué tal? ¿Cómo estás? ¿Qué haces? ¿Cómo va todo? ¿Cómo te encuentras? ¿Qué hay de nuevo? ¿Qué pasa? ¿Qué cuentas? ¿Qué onda? ¿Cómo te va? ¿Cómo te sientes? ¡Saludos! ¡Buen día! ¡Hola, qué tal! ¡Hola, ¿qué hubo? ¡Hey! ¡Hola, amigo! ¡Buenas! ¡Qué gusto verte! ¡Hola, buenos días! ¡Hola, buenas tardes! ¡Hola, buenas noches! ¿Cómo andas? ¿Qué tal va todo? ¿Qué tal estás? ¿Qué hay de tu vida? ¿Cómo te trata la vida? ¿Cómo te va en todo? ¡Hola, cómo estás! ¡Qué alegría verte! ¡Hola, qué tal estás! ¡Hola, cómo has estado! ¡Hola, ¿cómo te va? ¡Hola, ¿cómo estás hoy? ¡Buenas, ¿cómo estás? ¡Hola, ¿qué cuentas? ¡Hola, ¿qué tal estás hoy? ¡Hola, ¿qué tal te encuentras? ¡Hola, ¿cómo te sientes? ¡Hola, ¿cómo lo llevas? ¡Hola, ¿cómo lo has pasado? ¡Hola, ¿cómo te ha ido? ¡Hola, ¿cómo te encuentras? ¡Hola, ¿cómo va todo contigo? ¡Hola, ¿cómo va tu día? ¡Hola, ¿cómo va tu vida? ¡Hola, ¿cómo te ha tratado el día? ¡Hola, ¿cómo estás llevando el día? ¡H
# ...

# %%
df2 = df.copy()
df2 = df2[:20]
df2
# Out:
#                  saludos                             presentaciones  \
# 0                 ¡Hola!                            Hola, soy Juan.
# 1           Buenos días.               Me llamo María, mucho gusto.
# 2         Buenas tardes.                 Encantado, me llamo David.
# 3         Buenas noches.                      Soy Ana, ¿cómo estás?
# 4              ¿Qué tal?  Mi nombre es Carlos, un placer conocerte.
# 5           ¿Cómo estás?                     Puedes llamarme Laura.
# 6            ¿Qué haces?                     Hola, me dicen Javier.
# 7         ¿Cómo va todo?                          Soy Sofía, ¿y tú?
# 8   ¿Cómo te encuentras?           Me llamo Alejandro, ¿cómo estás?
# 9     ¿Qué hay de nuevo?                 Encantada, me llamo Marta.
# 10            ¿Qué pasa?                 Hola, soy Pablo, ¿qué tal?
# 11         ¿Qué cuentas?                     Soy Andrea, un placer.
# 12            ¿Qué onda?                      Me dicen Luis, ¿y tú?
# ...

# %%
df2
# Out:
#                                       recomendaciones               saludos  \
# 0   ¿Tienes alguna película o serie que recomendar...                ¡Hola!
# 1   ¿Podrías sugerirme una buena película para ver...          Buenos días.
# 2   ¿Qué película o serie me recomendarías para re...        Buenas tardes.
# 3   ¿Conoces alguna película emocionante que valga...        Buenas noches.
# 4   ¿Cuál es tu serie de televisión favorita en es...             ¿Qué tal?
# 5   ¿Alguna recomendación de película que me mante...          ¿Cómo estás?
# 6   ¿Qué película me recomendarías para ver con am...           ¿Qué haces?
# 7   ¿Hay alguna serie nueva que debería agregar a ...        ¿Cómo va todo?
# 8   ¿Puedes sugerirme una película divertida para ...  ¿Cómo te encuentras?
# 9   ¿Qué serie de televisión me mantendría entrete...    ¿Qué hay de nuevo?
# 10  ¿Cuál es la mejor película de tu género favori...            ¿Qué pasa?
# ...

# %%
from text2bow import generate_tokens
generate_tokens().info()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 from text2bow import generate_tokens
#       2 generate_tokens().info()
#
# ModuleNotFoundError: No module named 'text2bow'
