# %%
from app import home

# %%
import pandas as pd

# %%
df = pd.DataFrame(home)

# %%
titles = df['title'].values.tolist()
year = df['release_year'].values.tolist()
type = df['type'].values.tolist()

# %%
bin_searchs = [titles[i] + ' ' + type[i] + ' ' + str(year[i]) + ' poster' for  i in range(0,len(titles))]

# %%
bin_searchs[3], len(bin_searchs)
# Out:
# ('La casa de papel TV Show 2021 poster', 24)

# %%
import bing_image_downloader

# %%
from pathlib import Path
from bing_image_downloader import downloader

# %%
images_dir = []
for name in bin_searchs:
  path = Path(f'/css/images/{name}')
  if path.is_dir():
    print('el directorio existe no se descargo nada')
    continue
  else:
    print('el directorio no existia se creo uno y se descargo la imagen')
    downloader.download(name,limit=1,
                        adult_filter_off=True, force_replace=False, timeout=60,output_dir='./directory_test/')
    images_dir.append(str(path)+'/Image_1.jpg')
# Out:
# el directorio no existia se creo uno y se descargo la imagen
# [%] Downloading Images to /home/ackerman/Proyect-Movie-Recomendations-System-/directory_test/The Machinist Movie 2004 poster
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 1 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.themoviedb.org/t/p/original/7xXCGNE9dR0TJTFEEqq7ePzn6A1.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 1 images.
# el directorio no existia se creo uno y se descargo la imagen
# [%] Downloading Images to /home/ackerman/Proyect-Movie-Recomendations-System-/directory_test/House of Cards TV Show 2018 poster
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 1 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from http://vodzilla.co/wp-content/uploads/2015/02/house-of-cards.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 1 images.
# el directorio no existia se creo uno y se descargo la imagen
# [%] Downloading Images to /home/ackerman/Proyect-Movie-Recomendations-System-/directory_test/RESIDENT EVIL: Infinite Darkness TV Show 2021 poster
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 1 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.themoviedb.org/t/p/original/hJ4CPlusRH473QdNX3xUKWUX6as.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 1 images.
# el directorio no existia se creo uno y se descargo la imagen
# [%] Downloading Images to /home/ackerman/Proyect-Movie-Recomendations-System-/directory_test/La casa de papel TV Show 2021 poster
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 1 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://musicnonstop.uol.com.br/wp-content/uploads/2021/08/PT-BR_LCDP_S5_Main_Vertical_RGB_PRE.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 1 images.
# el directorio no existia se creo uno y se descargo la imagen
# [%] Downloading Images to /home/ackerman/Proyect-Movie-Recomendations-System-/directory_test/Poseidon Movie 2006 poster
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 1 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.themoviedb.org/t/p/original/5DZCBBHQTOWBXwOIWXQC50azsK4.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 1 images.
# el directorio no existia se creo uno y se descargo la imagen
# [%] Downloading Images to /home/ackerman/Proyect-Movie-Recomendations-System-/directory_test/Once Upon a Time in Mumbaai Movie 2010 poster
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 1 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://m.media-amazon.com/images/M/MV5BNWQzMTQ4ZTYtNzJkMi00OWE5LWEwYjctMTRkY2FhYTJmZWZhXkEyXkFqcGdeQXVyODE5NzE3OTE@._V1_FMjpg_UX1000_.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 1 images.
# el directorio no existia se creo uno y se descargo la imagen
# [%] Downloading Images to /home/ackerman/Proyect-Movie-Recomendations-System-/directory_test/Mars Attacks! Movie 1996 poster
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 1 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://image.tmdb.org/t/p/original/gCbAeXWkkv26JAcWk1lJw1MxOKZ.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 1 images.
# el directorio no existia se creo uno y se descargo la imagen
# [%] Downloading Images to /home/ackerman/Proyect-Movie-Recomendations-System-/directory_test/Space Cowboys Movie 2000 poster
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 1 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://image.tmdb.org/t/p/original/pEYuFVM7ebnDjzAcCKCOI9cuKXk.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 1 images.
# el directorio no existia se creo uno y se descargo la imagen
# [%] Downloading Images to /home/ackerman/Proyect-Movie-Recomendations-System-/directory_test/BEASTARS TV Show 2021 poster
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 1 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.themoviedb.org/t/p/original/1L7eNFzApgybUxWeX7cggaTmrGZ.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 1 images.
# el directorio no existia se creo uno y se descargo la imagen
# [%] Downloading Images to /home/ackerman/Proyect-Movie-Recomendations-System-/directory_test/Jaws Movie 1975 poster
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 1 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://johnsneaker.com/wp-content/uploads/2021/06/il_fullxfull.2372362535_fp33-scaled-1.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 1 images.
# el directorio no existia se creo uno y se descargo la imagen
# [%] Downloading Images to /home/ackerman/Proyect-Movie-Recomendations-System-/directory_test/Sex Education TV Show 2020 poster
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 1 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://videocelebs.net/contents/videos_screenshots/71000/71468/source/2.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 1 images.
# el directorio no existia se creo uno y se descargo la imagen
# [%] Downloading Images to /home/ackerman/Proyect-Movie-Recomendations-System-/directory_test/The Movies That Made Us TV Show 2021 poster
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 1 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://media.themoviedb.org/t/p/w600_and_h900_bestv2/1EpwMUmY6BhF1r082c3SYzR1rFP.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 1 images.
# el directorio no existia se creo uno y se descargo la imagen
# [%] Downloading Images to /home/ackerman/Proyect-Movie-Recomendations-System-/directory_test/Dear White People TV Show 2021 poster
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 1 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.indiewire.com/wp-content/uploads/2021/08/EN-US_DWP4_Main_Vertical_27x40_RGB_PRE20210805-4475-lz557k.jpg?w=691
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 1 images.
# el directorio no existia se creo uno y se descargo la imagen
# [%] Downloading Images to /home/ackerman/Proyect-Movie-Recomendations-System-/directory_test/Angry Birds TV Show 2018 poster
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 1 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://flxt.tmsimg.com/assets/p18157088_b_v13_ad.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 1 images.
# el directorio no existia se creo uno y se descargo la imagen
# [%] Downloading Images to /home/ackerman/Proyect-Movie-Recomendations-System-/directory_test/Dark Skies Movie 2013 poster
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 1 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from http://www.impawards.com/2013/posters/dark_skies_ver8_xxlg.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 1 images.
# el directorio no existia se creo uno y se descargo la imagen
# [%] Downloading Images to /home/ackerman/Proyect-Movie-Recomendations-System-/directory_test/The Prom Movie 2020 poster
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 1 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://de.web.img3.acsta.net/pictures/20/12/04/11/57/1868971.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 1 images.
# el directorio no existia se creo uno y se descargo la imagen
# [%] Downloading Images to /home/ackerman/Proyect-Movie-Recomendations-System-/directory_test/School of Rock Movie 2003 poster
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 1 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.themoviedb.org/t/p/original/rwAdo5ugCcPm17A99f4iPPNhuZK.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 1 images.
# el directorio no existia se creo uno y se descargo la imagen
# [%] Downloading Images to /home/ackerman/Proyect-Movie-Recomendations-System-/directory_test/Mary Magdalene Movie 2019 poster
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 1 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://images-na.ssl-images-amazon.com/images/I/91lBWxBdQlL._SL1500_.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 1 images.
# el directorio no existia se creo uno y se descargo la imagen
# [%] Downloading Images to /home/ackerman/Proyect-Movie-Recomendations-System-/directory_test/Shikara Movie 2020 poster
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 1 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.theindianwire.com/wp-content/uploads/2020/01/Shikara-Poster-3.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 1 images.
# el directorio no existia se creo uno y se descargo la imagen
# [%] Downloading Images to /home/ackerman/Proyect-Movie-Recomendations-System-/directory_test/Nailed It TV Show 2021 poster
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 1 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from http://www.impawards.com/tv/posters/nailed_it.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 1 images.
# el directorio no existia se creo uno y se descargo la imagen
# [%] Downloading Images to /home/ackerman/Proyect-Movie-Recomendations-System-/directory_test/Sparring Movie 2017 poster
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 1 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://m.media-amazon.com/images/M/MV5BYzczZDg4MWYtMjVkOS00ODJhLTk0ZGEtN2RiNWQwZTNkYjMxXkEyXkFqcGdeQXVyNDY2NDMxNDY@._V1_.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 1 images.
# el directorio no existia se creo uno y se descargo la imagen
# [%] Downloading Images to /home/ackerman/Proyect-Movie-Recomendations-System-/directory_test/The Seven Deadly Sins TV Show 2021 poster
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 1 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://m.media-amazon.com/images/M/MV5BYjQ3ZGQxNjItNzIwMi00N2ZiLTliY2QtZDU3MTIwZTY0OWU4XkEyXkFqcGdeQXVyODMyNTM0MjM@._V1_FMjpg_UX1000_.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 1 images.
# el directorio no existia se creo uno y se descargo la imagen
# [%] Downloading Images to /home/ackerman/Proyect-Movie-Recomendations-System-/directory_test/Naruto Shippuden the Movie: Blood Prison Movie 2011 poster
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 1 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://image.tmdb.org/t/p/original/4WT7zYFpe0fsbg6TitppiHddWAh.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 1 images.
# el directorio no existia se creo uno y se descargo la imagen
# [%] Downloading Images to /home/ackerman/Proyect-Movie-Recomendations-System-/directory_test/Marshall Movie 2017 poster
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 1 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.themoviedb.org/t/p/original/bz89IpQX5QayfWpwCYQN6s0vtRi.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 1 images.

# %%
images_dir
# Out:
# ['/css/images/The Machinist Movie 2004 poster/Image_1.jpg',
#  '/css/images/House of Cards TV Show 2018 poster/Image_1.jpg',
#  '/css/images/RESIDENT EVIL: Infinite Darkness TV Show 2021 poster/Image_1.jpg',
#  '/css/images/La casa de papel TV Show 2021 poster/Image_1.jpg',
#  '/css/images/Poseidon Movie 2006 poster/Image_1.jpg',
#  '/css/images/Once Upon a Time in Mumbaai Movie 2010 poster/Image_1.jpg',
#  '/css/images/Mars Attacks! Movie 1996 poster/Image_1.jpg',
#  '/css/images/Space Cowboys Movie 2000 poster/Image_1.jpg',
#  '/css/images/BEASTARS TV Show 2021 poster/Image_1.jpg',
#  '/css/images/Jaws Movie 1975 poster/Image_1.jpg',
#  '/css/images/Sex Education TV Show 2020 poster/Image_1.jpg',
#  '/css/images/The Movies That Made Us TV Show 2021 poster/Image_1.jpg',
#  '/css/images/Dear White People TV Show 2021 poster/Image_1.jpg',
#  '/css/images/Angry Birds TV Show 2018 poster/Image_1.jpg',
#  '/css/images/Dark Skies Movie 2013 poster/Image_1.jpg',
#  '/css/images/The Prom Movie 2020 poster/Image_1.jpg',
#  '/css/images/School of Rock Movie 2003 poster/Image_1.jpg',
#  '/css/images/Mary Magdalene Movie 2019 poster/Image_1.jpg',
#  '/css/images/Shikara Movie 2020 poster/Image_1.jpg',
#  '/css/images/Nailed It TV Show 2021 poster/Image_1.jpg',
#  '/css/images/Sparring Movie 2017 poster/Image_1.jpg',
#  '/css/images/The Seven Deadly Sins TV Show 2021 poster/Image_1.jpg',
#  '/css/images/Naruto Shippuden the Movie: Blood Prison Movie 2011 poster/Image_1.jpg',
#  '/css/images/Marshall Movie 2017 poster/Image_1.jpg']
